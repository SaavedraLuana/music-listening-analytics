# %% [markdown]
# <a href="https://colab.research.google.com/github/SaavedraLuana/music-listening-analytics/blob/main/music_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,Music")
# Out:
# Hello,Music

# %%
import pandas as pd

# %%
music = pd.read_csv("https://raw.githubusercontent.com/SaavedraLuana/music-listening-analytics/main/data/listening_history.csv")

# %%
music
# Out:
#          date  time          artist                        song
# 0  2026-09-09   NaN         Solange                      Almeda
# 1  2026-09-09   NaN         Solange                      Jerrod
# 2  2026-09-09   NaN          Kelela                      Linknb
# 3  2026-09-09   NaN          Kelela                      Sorbet
# 4  2026-09-09   NaN  PinkPantheress                      Reason
# 5  2026-09-09   NaN   Azealia Banks  Heavy Metal and Reflective
# 6  2026-09-09   NaN          SOPHIE    Is It Cold in the Water?
# 7  2026-09-09   NaN    Pearly Drops             Oppressive Face
# 8  2026-09-09   NaN       FKA twigs                Lightbeamers
# 9  2026-09-09   NaN        Operelly                Encyclopedia

# %%
music["song"].count()
# Out:
# np.int64(10)

# %%
music["artist"].nunique()
# Out:
# 8

# %%
music["artist"].value_counts().head(3)
# Out:
# artist
# Solange           2
# Kelela            2
# PinkPantheress    1
# Name: count, dtype: int64
